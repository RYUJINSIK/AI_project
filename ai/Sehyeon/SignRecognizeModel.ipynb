# %% [markdown]
# # 1. Import and Install Dependencies

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# # 2. Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture('SEN/05/NIA_SL_SEN0005_SYN05_D.mp4')
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    if cap.isOpened():
        frame_cnt = 0
        while True:
            # Read feed
            ret, frame = cap.read()
            if ret:
                frame_cnt += 1
                # Make detections
                image, results = mediapipe_detection(frame, holistic)
                print(results, frame_cnt)
                
                # Draw landmarks
                draw_styled_landmarks(image, results)

                # Show to screen
                cv2.imshow('OpenCV Feed', image)
                cv2.waitKey(25)
            else:
                break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 1
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 2
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 4
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 5
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 6
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 7
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 8
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 9
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 10
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 11
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 12
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 13
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 14
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 15
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 16
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 17
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 18
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 19
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 20
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 21
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 22
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 23
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 24
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 25
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 26
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 27
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 28
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 29
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 30
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 31
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 32
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 33
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 34
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 35
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 36
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 37
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 38
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 39
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 40
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 41
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 42
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 43
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 44
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 45
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 46
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 47
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 48
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 49
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 50
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 51
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 52
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 53
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 54
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 55
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 56
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 57
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 58
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 59
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 60
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 61
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 62
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 63
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 64
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 65
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 66
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 67
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 68
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 69
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 70
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 71
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 72
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 73
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 74
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 75
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 76
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 77
# <class 'mediapipe.python.solution_base.SolutionOutputs'> 78

# %%
draw_landmarks(frame, results)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\VSwork\CNN\Action Detection Refined.ipynb Cell 9' in <module>
# ----> <a href='vscode-notebook-cell:/d%3A/VSwork/CNN/Action%20Detection%20Refined.ipynb#ch0000043?line=0'>1</a> draw_landmarks(frame, results)
#
# d:\VSwork\CNN\Action Detection Refined.ipynb Cell 6' in draw_landmarks(image, results)
#       <a href='vscode-notebook-cell:/d%3A/VSwork/CNN/Action%20Detection%20Refined.ipynb#ch0000005?line=0'>1</a> def draw_landmarks(image, results):
# ----> <a href='vscode-notebook-cell:/d%3A/VSwork/CNN/Action%20Detection%20Refined.ipynb#ch0000005?line=1'>2</a>     mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION) # Draw face connections
#       <a href='vscode-notebook-cell:/d%3A/VSwork/CNN/Action%20Detection%20Refined.ipynb#ch0000005?line=2'>3</a>     mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
#       <a href='vscode-notebook-cell:/d%3A/VSwork/CNN/Action%20Detection%20Refined.ipynb#ch0000005?line=3'>4</a>     mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
#
# File d:\VSwork\CNN\venv\lib\site-packages\mediapipe\python\solutions\drawing_utils.py:155, in draw_landmarks(image, landmark_list, connections, landmark_drawing_spec, connection_drawing_spec)
#     <a href='file:///d%3A/VSwork/CNN/venv/lib/site-packages/mediapipe/python/solutions/drawing_utils.py?line=152'>153</a> if not landmark_list:
#     <a href='file:///d%3A/VSwork/CNN/venv/lib/site-packages/mediapipe/python/solutions/drawing_utils.py?line=153'>154</a>   return
# --> <a href='file:///d%3A/VSwork/CNN/venv/lib/site-packages/mediapipe/python/solutions/drawing_utils.py?line=154'>155</a> if image.shape[2] != _RGB_CHANNELS:
#     <a href='file:///d%3A/VSwork/CNN/venv/lib/site-packages/mediapipe/python/solutions/drawing_utils.py?line=155'>156</a>   raise ValueError('Input image must contain three channel rgb data.')
#     <a href='file:///d%3A/VSwork/CNN/venv/lib/site-packages/mediapipe/python/solutions/drawing_utils.py?line=156'>157</a> image_rows, image_cols, _ = image.shape
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # 3. Extract Keypoint Values

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
result_test = extract_keypoints(results)

# %%
result_test
# Out:
# array([ 0.54848254,  0.60028231, -0.72900838, ...,  0.        ,
#         0.        ,  0.        ])

# %%
np.save('0', result_test)

# %%
np.load('0.npy')
# Out:
# array([ 0.54848254,  0.60028231, -0.72900838, ...,  0.        ,
#         0.        ,  0.        ])

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 

# Actions that we try to detect
actions = np.array(['hello', 'thanks', 'iloveyou'])

# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# Folder start
start_folder = 1

# %%
for action in actions: 
    for sequence in range(1, no_sequences+1):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %% [markdown]
# # 5. Collect Keypoint Values for Training and Testing

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(start_folder, start_folder+no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(500)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'hello': 0, 'thanks': 1, 'iloveyou': 2}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (90, 30, 1662)

# %%
np.array(labels).shape
# Out:
# (90,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (90, 30, 1662)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_test.shape
# Out:
# (5, 3)

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# 3/3 [==============================] - 7s 108ms/step - loss: 3.6353 - categorical_accuracy: 0.3412
# Epoch 2/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 7.0813 - categorical_accuracy: 0.3412
# Epoch 3/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.2042 - categorical_accuracy: 0.3529
# Epoch 4/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.1350 - categorical_accuracy: 0.3647
# Epoch 5/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.2199 - categorical_accuracy: 0.2824
# Epoch 6/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0116 - categorical_accuracy: 0.4941
# Epoch 7/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.9416 - categorical_accuracy: 0.5059
# Epoch 8/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.9259 - categorical_accuracy: 0.5176
# Epoch 9/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.8608 - categorical_accuracy: 0.5882
# Epoch 10/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.8404 - categorical_accuracy: 0.5294
# Epoch 11/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.2104 - categorical_accuracy: 0.4824
# Epoch 12/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.1122 - categorical_accuracy: 0.4706
# Epoch 13/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.9997 - categorical_accuracy: 0.5059
# Epoch 14/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.9291 - categorical_accuracy: 0.5176
# Epoch 15/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0246 - categorical_accuracy: 0.4588
# Epoch 16/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.9568 - categorical_accuracy: 0.5059
# Epoch 17/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.2430 - categorical_accuracy: 0.3529
# Epoch 18/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.9735 - categorical_accuracy: 0.5294
# Epoch 19/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.0391 - categorical_accuracy: 0.4000
# Epoch 20/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.3896 - categorical_accuracy: 0.4471
# Epoch 21/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.5720 - categorical_accuracy: 0.2941
# Epoch 22/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.3634 - categorical_accuracy: 0.4118
# Epoch 23/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.6778 - categorical_accuracy: 0.3294
# Epoch 24/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.1637 - categorical_accuracy: 0.4706
# Epoch 25/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.2309 - categorical_accuracy: 0.3882
# Epoch 26/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.3993 - categorical_accuracy: 0.4235
# Epoch 27/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.3356 - categorical_accuracy: 0.3294
# Epoch 28/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.1139 - categorical_accuracy: 0.4000
# Epoch 29/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 1.1715 - categorical_accuracy: 0.3294
# Epoch 30/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.1111 - categorical_accuracy: 0.3529
# Epoch 31/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.1935 - categorical_accuracy: 0.3529
# Epoch 32/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.1824 - categorical_accuracy: 0.3176
# Epoch 33/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.0925 - categorical_accuracy: 0.3882
# Epoch 34/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.1867 - categorical_accuracy: 0.3765
# Epoch 35/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.1513 - categorical_accuracy: 0.2824
# Epoch 36/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 1.2362 - categorical_accuracy: 0.2941
# Epoch 37/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.1218 - categorical_accuracy: 0.4235
# Epoch 38/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.2030 - categorical_accuracy: 0.4235
# Epoch 39/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 1.4651 - categorical_accuracy: 0.4000
# Epoch 40/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 1.4320 - categorical_accuracy: 0.3529
# Epoch 41/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.3086 - categorical_accuracy: 0.4235
# Epoch 42/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.5542 - categorical_accuracy: 0.3529
# Epoch 43/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.2577 - categorical_accuracy: 0.4706
# Epoch 44/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.1949 - categorical_accuracy: 0.4353
# Epoch 45/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 1.3672 - categorical_accuracy: 0.3647
# Epoch 46/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 1.2525 - categorical_accuracy: 0.3882
# Epoch 47/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.2789 - categorical_accuracy: 0.4000
# Epoch 48/2000
# 3/3 [==============================] - 0s 127ms/step - loss: 1.3315 - categorical_accuracy: 0.3412
# Epoch 49/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.4090 - categorical_accuracy: 0.4824
# Epoch 50/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 2.1680 - categorical_accuracy: 0.3882
# Epoch 51/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 2.3341 - categorical_accuracy: 0.3647
# Epoch 52/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.7275 - categorical_accuracy: 0.2353
# Epoch 53/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.8884 - categorical_accuracy: 0.4588
# Epoch 54/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 2.8269 - categorical_accuracy: 0.3059
# Epoch 55/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 2.1119 - categorical_accuracy: 0.2824
# Epoch 56/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 2.7551 - categorical_accuracy: 0.2471
# Epoch 57/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 2.6490 - categorical_accuracy: 0.3647
# Epoch 58/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 2.3976 - categorical_accuracy: 0.3529
# Epoch 59/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 2.7651 - categorical_accuracy: 0.2824
# Epoch 60/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.4733 - categorical_accuracy: 0.3529
# Epoch 61/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.7371 - categorical_accuracy: 0.3529
# Epoch 62/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.4986 - categorical_accuracy: 0.3647
# Epoch 63/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.3218 - categorical_accuracy: 0.4471
# Epoch 64/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 1.2574 - categorical_accuracy: 0.3412
# Epoch 65/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.3322 - categorical_accuracy: 0.4235
# Epoch 66/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.8901 - categorical_accuracy: 0.3765
# Epoch 67/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.5643 - categorical_accuracy: 0.4118
# Epoch 68/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.6373 - categorical_accuracy: 0.2824
# Epoch 69/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 2.1319 - categorical_accuracy: 0.3529
# Epoch 70/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.4747 - categorical_accuracy: 0.3294
# Epoch 71/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.8747 - categorical_accuracy: 0.3647
# Epoch 72/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 2.6740 - categorical_accuracy: 0.2941
# Epoch 73/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 3.1976 - categorical_accuracy: 0.3059
# Epoch 74/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 4.7488 - categorical_accuracy: 0.3647
# Epoch 75/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 9.5877 - categorical_accuracy: 0.3176
# Epoch 76/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 11.0148 - categorical_accuracy: 0.3059
# Epoch 77/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 9.0156 - categorical_accuracy: 0.3647
# Epoch 78/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 46.4923 - categorical_accuracy: 0.3294
# Epoch 79/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 27.7076 - categorical_accuracy: 0.2118
# Epoch 80/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 31.8929 - categorical_accuracy: 0.3059
# Epoch 81/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 28.9232 - categorical_accuracy: 0.3412
# Epoch 82/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 6.1527 - categorical_accuracy: 0.3529
# Epoch 83/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 5.3655 - categorical_accuracy: 0.3647
# Epoch 84/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 3.5783 - categorical_accuracy: 0.3294
# Epoch 85/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 7.9080 - categorical_accuracy: 0.2824
# Epoch 86/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 26.9437 - categorical_accuracy: 0.2471
# Epoch 87/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 14.4579 - categorical_accuracy: 0.3765
# Epoch 88/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 11.3134 - categorical_accuracy: 0.3882
# Epoch 89/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 80.5514 - categorical_accuracy: 0.2706
# Epoch 90/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 69.1492 - categorical_accuracy: 0.2000
# Epoch 91/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 52.3533 - categorical_accuracy: 0.3412
# Epoch 92/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 39.1628 - categorical_accuracy: 0.3647
# Epoch 93/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 21.0581 - categorical_accuracy: 0.3176
# Epoch 94/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 17.9611 - categorical_accuracy: 0.3882
# Epoch 95/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 11.9313 - categorical_accuracy: 0.2588
# Epoch 96/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 10.3690 - categorical_accuracy: 0.3294
# Epoch 97/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 14.2033 - categorical_accuracy: 0.3059
# Epoch 98/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 7.2106 - categorical_accuracy: 0.2706
# Epoch 99/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 10.1957 - categorical_accuracy: 0.4118
# Epoch 100/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 3.3645 - categorical_accuracy: 0.3294
# Epoch 101/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 6.1380 - categorical_accuracy: 0.3294
# Epoch 102/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 3.2736 - categorical_accuracy: 0.4118
# Epoch 103/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 4.1791 - categorical_accuracy: 0.3176
# Epoch 104/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 2.8247 - categorical_accuracy: 0.4000
# Epoch 105/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 3.0103 - categorical_accuracy: 0.3412
# Epoch 106/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.8683 - categorical_accuracy: 0.4000
# Epoch 107/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 2.0288 - categorical_accuracy: 0.3059
# Epoch 108/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.4744 - categorical_accuracy: 0.3765
# Epoch 109/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.6254 - categorical_accuracy: 0.3412
# Epoch 110/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 2.5044 - categorical_accuracy: 0.2941
# Epoch 111/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 2.1067 - categorical_accuracy: 0.3529
# Epoch 112/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 2.7310 - categorical_accuracy: 0.3176
# Epoch 113/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 2.5272 - categorical_accuracy: 0.3647
# Epoch 114/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 2.4843 - categorical_accuracy: 0.3176
# Epoch 115/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.4476 - categorical_accuracy: 0.2706
# Epoch 116/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.9310 - categorical_accuracy: 0.4353
# Epoch 117/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.5560 - categorical_accuracy: 0.3294
# Epoch 118/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.5578 - categorical_accuracy: 0.4118
# Epoch 119/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 1.4613 - categorical_accuracy: 0.3529
# Epoch 120/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.4170 - categorical_accuracy: 0.3647
# Epoch 121/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.5577 - categorical_accuracy: 0.4353
# Epoch 122/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.6728 - categorical_accuracy: 0.4000
# Epoch 123/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.3654 - categorical_accuracy: 0.3647
# Epoch 124/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.1985 - categorical_accuracy: 0.4706
# Epoch 125/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.5274 - categorical_accuracy: 0.4471
# Epoch 126/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.6159 - categorical_accuracy: 0.3647
# Epoch 127/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.4111 - categorical_accuracy: 0.4235
# Epoch 128/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.7414 - categorical_accuracy: 0.3765
# Epoch 129/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.3811 - categorical_accuracy: 0.4118
# Epoch 130/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.1721 - categorical_accuracy: 0.4471
# Epoch 131/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.2600 - categorical_accuracy: 0.4471
# Epoch 132/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.3864 - categorical_accuracy: 0.3412
# Epoch 133/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.2602 - categorical_accuracy: 0.3882
# Epoch 134/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.8343 - categorical_accuracy: 0.3765
# Epoch 135/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 2.0802 - categorical_accuracy: 0.4353
# Epoch 136/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 2.4030 - categorical_accuracy: 0.4118
# Epoch 137/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.6203 - categorical_accuracy: 0.4000
# Epoch 138/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.4605 - categorical_accuracy: 0.3882
# Epoch 139/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.5139 - categorical_accuracy: 0.4235
# Epoch 140/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.8323 - categorical_accuracy: 0.4353
# Epoch 141/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.7746 - categorical_accuracy: 0.3882
# Epoch 142/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 2.5284 - categorical_accuracy: 0.4471
# Epoch 143/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 2.0130 - categorical_accuracy: 0.3765
# Epoch 144/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 2.1487 - categorical_accuracy: 0.4235
# Epoch 145/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.6613 - categorical_accuracy: 0.3882
# Epoch 146/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.7419 - categorical_accuracy: 0.4588
# Epoch 147/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 2.7345 - categorical_accuracy: 0.4118
# Epoch 148/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 2.6517 - categorical_accuracy: 0.4000
# Epoch 149/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 2.1894 - categorical_accuracy: 0.3882
# Epoch 150/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.6116 - categorical_accuracy: 0.4118
# Epoch 151/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.5617 - categorical_accuracy: 0.4588
# Epoch 152/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 2.1964 - categorical_accuracy: 0.4353
# Epoch 153/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 2.0954 - categorical_accuracy: 0.3765
# Epoch 154/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 2.1971 - categorical_accuracy: 0.3294
# Epoch 155/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.7366 - categorical_accuracy: 0.4235
# Epoch 156/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.8377 - categorical_accuracy: 0.3294
# Epoch 157/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.2540 - categorical_accuracy: 0.3882
# Epoch 158/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.5662 - categorical_accuracy: 0.4941
# Epoch 159/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 2.0677 - categorical_accuracy: 0.3882
# Epoch 160/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 2.2157 - categorical_accuracy: 0.3529
# Epoch 161/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 2.7744 - categorical_accuracy: 0.3765
# Epoch 162/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 2.3658 - categorical_accuracy: 0.3529
# Epoch 163/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 2.0595 - categorical_accuracy: 0.3529
# Epoch 164/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 2.5135 - categorical_accuracy: 0.4000
# Epoch 165/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 3.3441 - categorical_accuracy: 0.4353
# Epoch 166/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.6848 - categorical_accuracy: 0.4000
# Epoch 167/2000
# 3/3 [==============================] - 0s 166ms/step - loss: 2.0318 - categorical_accuracy: 0.3765
# Epoch 168/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.8365 - categorical_accuracy: 0.4118
# Epoch 169/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 1.8223 - categorical_accuracy: 0.4000
# Epoch 170/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.8320 - categorical_accuracy: 0.3765
# Epoch 171/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 2.0535 - categorical_accuracy: 0.2706
# Epoch 172/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 1.8487 - categorical_accuracy: 0.3412
# Epoch 173/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 2.7707 - categorical_accuracy: 0.4235
# Epoch 174/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.9815 - categorical_accuracy: 0.3882
# Epoch 175/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.9071 - categorical_accuracy: 0.4000
# Epoch 176/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.8168 - categorical_accuracy: 0.3882
# Epoch 177/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 2.6642 - categorical_accuracy: 0.3529
# Epoch 178/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 1.8799 - categorical_accuracy: 0.3412
# Epoch 179/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 2.5873 - categorical_accuracy: 0.3294
# Epoch 180/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.7039 - categorical_accuracy: 0.4118
# Epoch 181/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 3.1250 - categorical_accuracy: 0.4118
# Epoch 182/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 3.3024 - categorical_accuracy: 0.4000
# Epoch 183/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 3.0453 - categorical_accuracy: 0.3647
# Epoch 184/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 2.9024 - categorical_accuracy: 0.3529
# Epoch 185/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 3.0391 - categorical_accuracy: 0.3882
# Epoch 186/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 2.4656 - categorical_accuracy: 0.4706
# Epoch 187/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 3.1333 - categorical_accuracy: 0.4706
# Epoch 188/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.6747 - categorical_accuracy: 0.4000
# Epoch 189/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.7329 - categorical_accuracy: 0.4353
# Epoch 190/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 2.1883 - categorical_accuracy: 0.4118
# Epoch 191/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.9872 - categorical_accuracy: 0.4471
# Epoch 192/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.6334 - categorical_accuracy: 0.4941
# Epoch 193/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 25.3057 - categorical_accuracy: 0.2941
# Epoch 194/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 12.1384 - categorical_accuracy: 0.3647
# Epoch 195/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 15.1531 - categorical_accuracy: 0.3647
# Epoch 196/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 4.9940 - categorical_accuracy: 0.3059
# Epoch 197/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 2.5876 - categorical_accuracy: 0.4235
# Epoch 198/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 2.7108 - categorical_accuracy: 0.2706
# Epoch 199/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 2.2905 - categorical_accuracy: 0.4000
# Epoch 200/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 2.3569 - categorical_accuracy: 0.4588
# Epoch 201/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 2.3136 - categorical_accuracy: 0.4000
# Epoch 202/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.0116 - categorical_accuracy: 0.4588
# Epoch 203/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 2.7418 - categorical_accuracy: 0.3882
# Epoch 204/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 2.0509 - categorical_accuracy: 0.3647
# Epoch 205/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.6554 - categorical_accuracy: 0.3647
# Epoch 206/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.7222 - categorical_accuracy: 0.4353
# Epoch 207/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.6953 - categorical_accuracy: 0.3882
# Epoch 208/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.6501 - categorical_accuracy: 0.4588
# Epoch 209/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.6525 - categorical_accuracy: 0.4588
# Epoch 210/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.6457 - categorical_accuracy: 0.4588
# Epoch 211/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.5344 - categorical_accuracy: 0.4471
# Epoch 212/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.8410 - categorical_accuracy: 0.4353
# Epoch 213/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.5089 - categorical_accuracy: 0.4118
# Epoch 214/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.5789 - categorical_accuracy: 0.4588
# Epoch 215/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.7017 - categorical_accuracy: 0.4000
# Epoch 216/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.6490 - categorical_accuracy: 0.3529
# Epoch 217/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 2.1837 - categorical_accuracy: 0.4471
# Epoch 218/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.9208 - categorical_accuracy: 0.3882
# Epoch 219/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.9225 - categorical_accuracy: 0.4000
# Epoch 220/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.5364 - categorical_accuracy: 0.4824
# Epoch 221/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.5956 - categorical_accuracy: 0.4588
# Epoch 222/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.5824 - categorical_accuracy: 0.4471
# Epoch 223/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.5132 - categorical_accuracy: 0.4824
# Epoch 224/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.4377 - categorical_accuracy: 0.4353
# Epoch 225/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.5380 - categorical_accuracy: 0.4588
# Epoch 226/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.3816 - categorical_accuracy: 0.4471
# Epoch 227/2000
# 3/3 [==============================] - 0s 176ms/step - loss: 1.4601 - categorical_accuracy: 0.5176
# Epoch 228/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.4035 - categorical_accuracy: 0.3647
# Epoch 229/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.3576 - categorical_accuracy: 0.4588
# Epoch 230/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.5195 - categorical_accuracy: 0.4824
# Epoch 231/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.4394 - categorical_accuracy: 0.4235
# Epoch 232/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.4941 - categorical_accuracy: 0.4824
# Epoch 233/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.5487 - categorical_accuracy: 0.3529
# Epoch 234/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.4046 - categorical_accuracy: 0.4706
# Epoch 235/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.5563 - categorical_accuracy: 0.3294
# Epoch 236/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 1.3951 - categorical_accuracy: 0.4118
# Epoch 237/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 1.3913 - categorical_accuracy: 0.4588
# Epoch 238/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.3658 - categorical_accuracy: 0.3765
# Epoch 239/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.3126 - categorical_accuracy: 0.4941
# Epoch 240/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.3270 - categorical_accuracy: 0.4588
# Epoch 241/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.3616 - categorical_accuracy: 0.4353
# Epoch 242/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.3028 - categorical_accuracy: 0.4235
# Epoch 243/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.5013 - categorical_accuracy: 0.4000
# Epoch 244/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.4902 - categorical_accuracy: 0.3882
# Epoch 245/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 1.4807 - categorical_accuracy: 0.4471
# Epoch 246/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.3175 - categorical_accuracy: 0.4588
# Epoch 247/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.4116 - categorical_accuracy: 0.3882
# Epoch 248/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.4254 - categorical_accuracy: 0.4235
# Epoch 249/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.5581 - categorical_accuracy: 0.3412
# Epoch 250/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.4293 - categorical_accuracy: 0.4471
# Epoch 251/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.3488 - categorical_accuracy: 0.3294
# Epoch 252/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.3999 - categorical_accuracy: 0.4824
# Epoch 253/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.2504 - categorical_accuracy: 0.4706
# Epoch 254/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.3079 - categorical_accuracy: 0.4353
# Epoch 255/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.4397 - categorical_accuracy: 0.4235
# Epoch 256/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.9194 - categorical_accuracy: 0.2941
# Epoch 257/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.8930 - categorical_accuracy: 0.4353
# Epoch 258/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.5192 - categorical_accuracy: 0.4118
# Epoch 259/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.8703 - categorical_accuracy: 0.4588
# Epoch 260/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.6655 - categorical_accuracy: 0.3882
# Epoch 261/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 251.8509 - categorical_accuracy: 0.4353
# Epoch 262/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 39.3705 - categorical_accuracy: 0.3059
# Epoch 263/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.6957 - categorical_accuracy: 0.4588
# Epoch 264/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.3548 - categorical_accuracy: 0.3765
# Epoch 265/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.5805 - categorical_accuracy: 0.4000
# Epoch 266/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.9874 - categorical_accuracy: 0.4000
# Epoch 267/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 21.0002 - categorical_accuracy: 0.3882
# Epoch 268/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 3.1659 - categorical_accuracy: 0.3882
# Epoch 269/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.8992 - categorical_accuracy: 0.3176
# Epoch 270/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 2.0182 - categorical_accuracy: 0.2941
# Epoch 271/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 2.1498 - categorical_accuracy: 0.3059
# Epoch 272/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.9479 - categorical_accuracy: 0.2706
# Epoch 273/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 2.0024 - categorical_accuracy: 0.2706
# Epoch 274/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.3729 - categorical_accuracy: 0.3647
# Epoch 275/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 1.2833 - categorical_accuracy: 0.3294
# Epoch 276/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.5086 - categorical_accuracy: 0.2588
# Epoch 277/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.1895 - categorical_accuracy: 0.3647
# Epoch 278/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.0845 - categorical_accuracy: 0.4235
# Epoch 279/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.1694 - categorical_accuracy: 0.2706
# Epoch 280/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.2155 - categorical_accuracy: 0.3412
# Epoch 281/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.1164 - categorical_accuracy: 0.4235
# Epoch 282/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.2195 - categorical_accuracy: 0.3529
# Epoch 283/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.1270 - categorical_accuracy: 0.4118
# Epoch 284/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 1.1669 - categorical_accuracy: 0.4000
# Epoch 285/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.1484 - categorical_accuracy: 0.4118
# Epoch 286/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.1630 - categorical_accuracy: 0.3529
# Epoch 287/2000
# 3/3 [==============================] - 0s 193ms/step - loss: 1.2804 - categorical_accuracy: 0.4471
# Epoch 288/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.5310 - categorical_accuracy: 0.3294
# Epoch 289/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.5962 - categorical_accuracy: 0.4118
# Epoch 290/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 1.7151 - categorical_accuracy: 0.3059
# Epoch 291/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.3725 - categorical_accuracy: 0.4588
# Epoch 292/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.3267 - categorical_accuracy: 0.3647
# Epoch 293/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.4303 - categorical_accuracy: 0.4235
# Epoch 294/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.4310 - categorical_accuracy: 0.3059
# Epoch 295/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.2798 - categorical_accuracy: 0.4235
# Epoch 296/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.2527 - categorical_accuracy: 0.3412
# Epoch 297/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.6556 - categorical_accuracy: 0.4588
# Epoch 298/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.6677 - categorical_accuracy: 0.3176
# Epoch 299/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.6601 - categorical_accuracy: 0.4000
# Epoch 300/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 1.4812 - categorical_accuracy: 0.4235
# Epoch 301/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.2790 - categorical_accuracy: 0.3765
# Epoch 302/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.4515 - categorical_accuracy: 0.3294
# Epoch 303/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.4701 - categorical_accuracy: 0.4235
# Epoch 304/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.5364 - categorical_accuracy: 0.3176
# Epoch 305/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 1.2750 - categorical_accuracy: 0.4471
# Epoch 306/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 1.2146 - categorical_accuracy: 0.4235
# Epoch 307/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.1023 - categorical_accuracy: 0.4471
# Epoch 308/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.1666 - categorical_accuracy: 0.4235
# Epoch 309/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.1806 - categorical_accuracy: 0.4471
# Epoch 310/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.1430 - categorical_accuracy: 0.3529
# Epoch 311/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 1.3021 - categorical_accuracy: 0.4588
# Epoch 312/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.1160 - categorical_accuracy: 0.3765
# Epoch 313/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 1.1633 - categorical_accuracy: 0.4706
# Epoch 314/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.1824 - categorical_accuracy: 0.3647
# Epoch 315/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.1955 - categorical_accuracy: 0.4941
# Epoch 316/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.0811 - categorical_accuracy: 0.4353
# Epoch 317/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.1332 - categorical_accuracy: 0.5059
# Epoch 318/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.0813 - categorical_accuracy: 0.4588
# Epoch 319/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.2588 - categorical_accuracy: 0.4471
# Epoch 320/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0077 - categorical_accuracy: 0.5176
# Epoch 321/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0853 - categorical_accuracy: 0.4941
# Epoch 322/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.1178 - categorical_accuracy: 0.4000
# Epoch 323/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.1392 - categorical_accuracy: 0.5412
# Epoch 324/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.1475 - categorical_accuracy: 0.4118
# Epoch 325/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.1704 - categorical_accuracy: 0.5412
# Epoch 326/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.0183 - categorical_accuracy: 0.4824
# Epoch 327/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.9455 - categorical_accuracy: 0.5765
# Epoch 328/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.9631 - categorical_accuracy: 0.5882
# Epoch 329/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.0859 - categorical_accuracy: 0.4706
# Epoch 330/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.0940 - categorical_accuracy: 0.5412
# Epoch 331/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 1.0588 - categorical_accuracy: 0.4353
# Epoch 332/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 1.0099 - categorical_accuracy: 0.5647
# Epoch 333/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.0137 - categorical_accuracy: 0.5412
# Epoch 334/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0425 - categorical_accuracy: 0.5059
# Epoch 335/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0199 - categorical_accuracy: 0.4824
# Epoch 336/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.0101 - categorical_accuracy: 0.5882
# Epoch 337/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.0060 - categorical_accuracy: 0.5882
# Epoch 338/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.9504 - categorical_accuracy: 0.5647
# Epoch 339/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.9137 - categorical_accuracy: 0.5765
# Epoch 340/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.9245 - categorical_accuracy: 0.5882
# Epoch 341/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.9068 - categorical_accuracy: 0.6235
# Epoch 342/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0241 - categorical_accuracy: 0.5412
# Epoch 343/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 1.0134 - categorical_accuracy: 0.4824
# Epoch 344/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.0470 - categorical_accuracy: 0.5294
# Epoch 345/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.0384 - categorical_accuracy: 0.4824
# Epoch 346/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.2121 - categorical_accuracy: 0.5176
# Epoch 347/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.0562 - categorical_accuracy: 0.4588
# Epoch 348/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 1.1090 - categorical_accuracy: 0.5412
# Epoch 349/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.9857 - categorical_accuracy: 0.4824
# Epoch 350/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.7730 - categorical_accuracy: 0.4824
# Epoch 351/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.1696 - categorical_accuracy: 0.5059
# Epoch 352/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.1530 - categorical_accuracy: 0.3176
# Epoch 353/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.1253 - categorical_accuracy: 0.4941
# Epoch 354/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 1.1006 - categorical_accuracy: 0.4353
# Epoch 355/2000
# 3/3 [==============================] - 0s 108ms/step - loss: 1.0767 - categorical_accuracy: 0.4824
# Epoch 356/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 1.1148 - categorical_accuracy: 0.4588
# Epoch 357/2000
# 3/3 [==============================] - 0s 126ms/step - loss: 0.9496 - categorical_accuracy: 0.5529
# Epoch 358/2000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.9761 - categorical_accuracy: 0.5412
# Epoch 359/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 1.0803 - categorical_accuracy: 0.4118
# Epoch 360/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 0.9676 - categorical_accuracy: 0.5647
# Epoch 361/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 1.0787 - categorical_accuracy: 0.4471
# Epoch 362/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 1.1748 - categorical_accuracy: 0.4588
# Epoch 363/2000
# 3/3 [==============================] - 0s 109ms/step - loss: 0.9105 - categorical_accuracy: 0.5765
# Epoch 364/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 0.9404 - categorical_accuracy: 0.5176
# Epoch 365/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.9322 - categorical_accuracy: 0.4941
# Epoch 366/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.9554 - categorical_accuracy: 0.5647
# Epoch 367/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.9478 - categorical_accuracy: 0.5176
# Epoch 368/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.9779 - categorical_accuracy: 0.5647
# Epoch 369/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.9784 - categorical_accuracy: 0.5647
# Epoch 370/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.9010 - categorical_accuracy: 0.5529
# Epoch 371/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.9308 - categorical_accuracy: 0.5647
# Epoch 372/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.9545 - categorical_accuracy: 0.5647
# Epoch 373/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.9152 - categorical_accuracy: 0.6118
# Epoch 374/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.9334 - categorical_accuracy: 0.5765
# Epoch 375/2000
# 3/3 [==============================] - 0s 109ms/step - loss: 0.9034 - categorical_accuracy: 0.5882
# Epoch 376/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.9317 - categorical_accuracy: 0.5412
# Epoch 377/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.9466 - categorical_accuracy: 0.6118
# Epoch 378/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.9499 - categorical_accuracy: 0.5412
# Epoch 379/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.9150 - categorical_accuracy: 0.5647
# Epoch 380/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.9505 - categorical_accuracy: 0.5647
# Epoch 381/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.0852 - categorical_accuracy: 0.5765
# Epoch 382/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.9719 - categorical_accuracy: 0.4588
# Epoch 383/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.9194 - categorical_accuracy: 0.5882
# Epoch 384/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.9420 - categorical_accuracy: 0.5647
# Epoch 385/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.9088 - categorical_accuracy: 0.6000
# Epoch 386/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.9017 - categorical_accuracy: 0.6235
# Epoch 387/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.9506 - categorical_accuracy: 0.5647
# Epoch 388/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.9189 - categorical_accuracy: 0.5765
# Epoch 389/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.8691 - categorical_accuracy: 0.6118
# Epoch 390/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.8601 - categorical_accuracy: 0.6353
# Epoch 391/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.9919 - categorical_accuracy: 0.5176
# Epoch 392/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.8830 - categorical_accuracy: 0.6235
# Epoch 393/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.9085 - categorical_accuracy: 0.6353
# Epoch 394/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 0.9494 - categorical_accuracy: 0.5882
# Epoch 395/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.9828 - categorical_accuracy: 0.4941
# Epoch 396/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.9577 - categorical_accuracy: 0.5647
# Epoch 397/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.8750 - categorical_accuracy: 0.6118
# Epoch 398/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.9147 - categorical_accuracy: 0.5882
# Epoch 399/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.9941 - categorical_accuracy: 0.4353
# Epoch 400/2000
# 3/3 [==============================] - 0s 109ms/step - loss: 1.0652 - categorical_accuracy: 0.5882
# Epoch 401/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.0131 - categorical_accuracy: 0.5529
# Epoch 402/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.9105 - categorical_accuracy: 0.6000
# Epoch 403/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 0.8772 - categorical_accuracy: 0.6353
# Epoch 404/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.8988 - categorical_accuracy: 0.6235
# Epoch 405/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 0.8112 - categorical_accuracy: 0.6000
# Epoch 406/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.8655 - categorical_accuracy: 0.5765
# Epoch 407/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.8283 - categorical_accuracy: 0.6000
# Epoch 408/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.7967 - categorical_accuracy: 0.6000
# Epoch 409/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.8439 - categorical_accuracy: 0.6353
# Epoch 410/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.8395 - categorical_accuracy: 0.5765
# Epoch 411/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.7902 - categorical_accuracy: 0.5882
# Epoch 412/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.8246 - categorical_accuracy: 0.6588
# Epoch 413/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.8149 - categorical_accuracy: 0.6000
# Epoch 414/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.7878 - categorical_accuracy: 0.6000
# Epoch 415/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.8212 - categorical_accuracy: 0.6471
# Epoch 416/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.8548 - categorical_accuracy: 0.6235
# Epoch 417/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.8886 - categorical_accuracy: 0.5882
# Epoch 418/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.8064 - categorical_accuracy: 0.6941
# Epoch 419/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.9282 - categorical_accuracy: 0.6118
# Epoch 420/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.8579 - categorical_accuracy: 0.5647
# Epoch 421/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.7681 - categorical_accuracy: 0.6471
# Epoch 422/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.7468 - categorical_accuracy: 0.6353
# Epoch 423/2000
# 3/3 [==============================] - 0s 80ms/step - loss: 0.7848 - categorical_accuracy: 0.6118
# Epoch 424/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.7781 - categorical_accuracy: 0.6471
# Epoch 425/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.7354 - categorical_accuracy: 0.6471
# Epoch 426/2000
# ...
# Epoch 1862/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0020 - categorical_accuracy: 1.0000
# Epoch 1863/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 1864/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 1865/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 0.0020 - categorical_accuracy: 1.0000
# Epoch 1866/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 1867/2000
# 3/3 [==============================] - 0s 108ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 1868/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 1869/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 1870/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 1871/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 1872/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 1873/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 1874/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 1875/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 1876/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0017 - categorical_accuracy: 1.0000
# Epoch 1877/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 1878/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 1879/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 1880/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 1881/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 1882/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 0.0017 - categorical_accuracy: 1.0000
# Epoch 1883/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 1884/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 1885/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0017 - categorical_accuracy: 1.0000
# Epoch 1886/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 1887/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0017 - categorical_accuracy: 1.0000
# Epoch 1888/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0016 - categorical_accuracy: 1.0000
# Epoch 1889/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 1890/2000
# 3/3 [==============================] - 0s 109ms/step - loss: 0.0017 - categorical_accuracy: 1.0000
# Epoch 1891/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 0.0016 - categorical_accuracy: 1.0000
# Epoch 1892/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0017 - categorical_accuracy: 1.0000
# Epoch 1893/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0017 - categorical_accuracy: 1.0000
# Epoch 1894/2000
# 3/3 [==============================] - 0s 106ms/step - loss: 0.0017 - categorical_accuracy: 1.0000
# Epoch 1895/2000
# 3/3 [==============================] - 0s 122ms/step - loss: 0.0015 - categorical_accuracy: 1.0000
# Epoch 1896/2000
# 3/3 [==============================] - 0s 111ms/step - loss: 0.0017 - categorical_accuracy: 1.0000
# Epoch 1897/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 0.0017 - categorical_accuracy: 1.0000
# Epoch 1898/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 0.0017 - categorical_accuracy: 1.0000
# Epoch 1899/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0017 - categorical_accuracy: 1.0000
# Epoch 1900/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0015 - categorical_accuracy: 1.0000
# Epoch 1901/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0016 - categorical_accuracy: 1.0000
# Epoch 1902/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0016 - categorical_accuracy: 1.0000
# Epoch 1903/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0015 - categorical_accuracy: 1.0000
# Epoch 1904/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 0.0016 - categorical_accuracy: 1.0000
# Epoch 1905/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0016 - categorical_accuracy: 1.0000
# Epoch 1906/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0016 - categorical_accuracy: 1.0000
# Epoch 1907/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 1908/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0017 - categorical_accuracy: 1.0000
# Epoch 1909/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 0.0016 - categorical_accuracy: 1.0000
# Epoch 1910/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0016 - categorical_accuracy: 1.0000
# Epoch 1911/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 0.0016 - categorical_accuracy: 1.0000
# Epoch 1912/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.0016 - categorical_accuracy: 1.0000
# Epoch 1913/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0015 - categorical_accuracy: 1.0000
# Epoch 1914/2000
# 3/3 [==============================] - 0s 111ms/step - loss: 0.0015 - categorical_accuracy: 1.0000
# Epoch 1915/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 0.0016 - categorical_accuracy: 1.0000
# Epoch 1916/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0015 - categorical_accuracy: 1.0000
# Epoch 1917/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0015 - categorical_accuracy: 1.0000
# Epoch 1918/2000
# 3/3 [==============================] - 0s 122ms/step - loss: 0.0016 - categorical_accuracy: 1.0000
# Epoch 1919/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 0.0015 - categorical_accuracy: 1.0000
# Epoch 1920/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 0.0015 - categorical_accuracy: 1.0000
# Epoch 1921/2000
# 3/3 [==============================] - 0s 121ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 1922/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0015 - categorical_accuracy: 1.0000
# Epoch 1923/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 1924/2000
# 3/3 [==============================] - 0s 123ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 1925/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 1926/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 1927/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 1928/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 1929/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 1930/2000
# 3/3 [==============================] - 0s 108ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 1931/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 1932/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 1933/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 1934/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0013 - categorical_accuracy: 1.0000
# Epoch 1935/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0013 - categorical_accuracy: 1.0000
# Epoch 1936/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0013 - categorical_accuracy: 1.0000
# Epoch 1937/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0013 - categorical_accuracy: 1.0000
# Epoch 1938/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0013 - categorical_accuracy: 1.0000
# Epoch 1939/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0013 - categorical_accuracy: 1.0000
# Epoch 1940/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 0.0013 - categorical_accuracy: 1.0000
# Epoch 1941/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0013 - categorical_accuracy: 1.0000
# Epoch 1942/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 1943/2000
# 3/3 [==============================] - 0s 126ms/step - loss: 0.0013 - categorical_accuracy: 1.0000
# Epoch 1944/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 1945/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0013 - categorical_accuracy: 1.0000
# Epoch 1946/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 1947/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0013 - categorical_accuracy: 1.0000
# Epoch 1948/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 0.0013 - categorical_accuracy: 1.0000
# Epoch 1949/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0013 - categorical_accuracy: 1.0000
# Epoch 1950/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.0013 - categorical_accuracy: 1.0000
# Epoch 1951/2000
# 3/3 [==============================] - 0s 122ms/step - loss: 0.0013 - categorical_accuracy: 1.0000
# Epoch 1952/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 1953/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 0.0013 - categorical_accuracy: 1.0000
# Epoch 1954/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 1955/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 0.0013 - categorical_accuracy: 1.0000
# Epoch 1956/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 1957/2000
# 3/3 [==============================] - 0s 111ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 1958/2000
# 3/3 [==============================] - 0s 106ms/step - loss: 0.0013 - categorical_accuracy: 1.0000
# Epoch 1959/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 1960/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 1961/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 1962/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 1963/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 1964/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 1965/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 1966/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 1967/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 1968/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 1969/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 1970/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 1971/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 1972/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 1973/2000
# 3/3 [==============================] - 0s 126ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 1974/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 1975/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 1976/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 1977/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 1978/2000
# 3/3 [==============================] - 0s 109ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 1979/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 1980/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 1981/2000
# 3/3 [==============================] - 0s 106ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 1982/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 1983/2000
# 3/3 [==============================] - 0s 112ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 1984/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 1985/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 1986/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 1987/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 1988/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 1989/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 1990/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0010 - categorical_accuracy: 1.0000
# Epoch 1991/2000
# 3/3 [==============================] - 0s 111ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 1992/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 1993/2000
# 3/3 [==============================] - 0s 106ms/step - loss: 0.0010 - categorical_accuracy: 1.0000
# Epoch 1994/2000
# 3/3 [==============================] - 0s 126ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 1995/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 1996/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0010 - categorical_accuracy: 1.0000
# Epoch 1997/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 1998/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0010 - categorical_accuracy: 1.0000
# Epoch 1999/2000
# 3/3 [==============================] - 0s 108ms/step - loss: 0.0010 - categorical_accuracy: 1.0000
# Epoch 2000/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 0.0010 - categorical_accuracy: 1.0000

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 64)            442112
#
#  lstm_1 (LSTM)               (None, 30, 128)           98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 596,675
# Trainable params: 596,675
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 8. Make Predictions

# %%
res = model.predict(X_test)

# %%
actions[np.argmax(res[4])]
# Out:
# 'iloveyou'

# %%
actions[np.argmax(y_test[4])]
# Out:
# 'thanks'

# %% [markdown]
# # 9. Save Weights

# %%
model.save('action.h5')

# %%
del model

# %%
model = load_model('action.h5')

# %%
model.load_weights('action.h5')

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[2, 1],
#         [1, 1]],
#
#        [[3, 0],
#         [2, 0]],
#
#        [[1, 3],
#         [1, 0]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.2

# %% [markdown]
# # 11. Test in Real Time

# %%
from scipy import stats

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
